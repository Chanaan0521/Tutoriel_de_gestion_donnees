# %%
#importation des librairies

import pandas as pd
import numpy as np

# %%
#Charger le fichier à travailler

source = "data/lesson-spreadsheet/HDR 2007-2008 Table 21.xlsx"

df = pd.read_excel(source)
df.head(14)
# Out:
#                                            Unnamed: 0              Unnamed: 1  \
# 0                                                 NaN                     NaN
# 1   21 Unemployment and informal sector work in no...                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                                           HDI rank                     NaN
# ...

# %%
#Nettoyage des colonnes vide

df = df.dropna(how = 'all', axis = 1)

# %%
#Nettoyage des lignes vides

df = df.dropna(how = 'all', axis = 0).reset_index(drop=True)

# %%
df.head(6)
# Out:
#                                           Unnamed: 0 Unnamed: 1  \
# 0  21 Unemployment and informal sector work in no...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                           HDI rank        NaN
# 4                                                NaN        NaN
# 5                             HIGH HUMAN DEVELOPMENT        NaN
#
#   … to have access to the resources needed for a decent standard of living …  \
# 0                                                NaN
# 1                                                NaN
# 2                     Unemployed people\n(thousands)
# 3                                                NaN
# 4                                         1996-2005d
# 5                                                NaN
#
#   Unnamed: 4                  Unnamed: 5 Unnamed: 6  \
# 0        NaN                         NaN        NaN
# ...

# %%
#Charger le fichier à travailler

source = "data/lesson-spreadsheet/HDR 2007-2008 Table 21.xlsx"

df = pd.read_excel(source, header=9)

#Nettoyage des colonnes vide

df = df.dropna(how = 'all', axis = 1)

#Nettoyage des lignes vides

df = df.dropna(how = 'all', axis = 0).reset_index(drop=True)

df.head(6)
# Out:
#                Unnamed: 0              Unnamed: 1  \
# 0                     NaN                     NaN
# 1                HDI rank                     NaN
# 2                     NaN                     NaN
# 3  HIGH HUMAN DEVELOPMENT                     NaN
# 4                      21  Hong Kong, China (SAR)
# 5                      23                  Israel
#
#                        Unnamed: 3 Unnamed: 4                  Unnamed: 5  \
# 0  Unemployed people\n(thousands)        NaN          Unemployment ratea
# 1                             NaN        NaN  Total\n(% of labour force)
# 2                      1996-2005d        NaN                  1996-2005d
# 3                             NaN        NaN                         NaN
# 4                             201        NaN                         5.6
# 5                             246        NaN                         9.0
#
#   Unnamed: 6                 Unnamed: 7 Unnamed: 8  \
# ...

# %%
#Obtenir les valeurs des 3 premières lignes et les conserver

columns = []
for c in df.columns:
    columns.append([str(v) for v in df[c][:3] if pd.notnull(v)])
columns
# Out:
# [['HDI rank'],
#  [],
#  ['Unemployed people\n(thousands)', '1996-2005d'],
#  [],
#  ['Unemployment ratea', 'Total\n(% of labour force)', '1996-2005d'],
#  [],
#  ['Female \n(% of male rate)', '1996-2005d'],
#  [],
#  ['Employment by economic activityb',
#   'Total                                  (thousands)',
#   '1996-2005d'],
#  [],
#  ['Agriculture\n(%)', '1996-2005d'],
#  [],
#  ['Industry\n(%)', '1996-2005d'],
#  [],
#  ['Services\n(%)', '1996-2005d'],
#  [],
#  ['Employment in informal sector as a % of non-agricultural employmentc',
#   'Survey year'],
#  [],
#  ['Both sexes\n(%)'],
#  [],
#  ['Female \n(%)'],
#  [],
#  ['Male \n(%)'],
#  []]

# %%
columns = [
    'HDI rank',
    'Country',
    'Unemployed people\n(thousands) 1996-2005',
    'Référence 1',
    'Unemployment rate Total\n(% of labour force) 1996-2005',
    'Référence 2',
    'Unemployment rate Female \n(% of male rate) 1996-2005',
    'Référence 3',
    'Employment by economic activity Total (thousands) 1996-2005d',
    'Référence 4',
    'Employment by economic activity Agriculture\n(%) 1996-2005',
    'Référence 5',
    'Employment by economic activity Industry\n(%) 1996-2005',
    'Référence 6',
    'Employment by economic activity Services\n(%) 1996-2005',
    'Référence 7',
    'Employment in informal sector as a % of non-agricultural employment Survey year Both sexes\n(%)',
    'Référence 8',
    'Employment in informal sector as a % of non-agricultural employment Survey year Female \n(%)',
    'Référence 9',
    'Employment in informal sector as a % of non-agricultural employment Survey year Male \n(%)',
    'Référence 10'

]

# Réinitialiser les colonnes des cadres de données
df.columns = columns
#Supprimer les lignes qui contenaient les informations que nous avons déjà et réinitialiser l'index
df = df.drop(np.arange(3), axis=0).reset_index(drop=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-608288fd1eba> in <module>
#      26
#      27 # Réinitialiser les colonnes des cadres de données
# ---> 28 df.columns = columns
#      29 #Supprimer les lignes qui contenaient les informations que nous avons déjà et réinitialiser l'index
#      30 df = df.drop(np.arange(3), axis=0).reset_index(drop=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     659
# ...

# %%
columns = [
    
]

# %%
columns =[
    'HDI rank',
    'Country',
    'Unemployed people\n(thousands) 1996-2005',
    'Référence 1',
    'Unemployment rate Total\n(% of labour force) 1996-2005',
    'Référence 2',
    'Unemployment rate Female \n(% of male rate) 1996-2005',
    'Référence 3',
    'Employment by economic activity Total (thousands) 1996-2005',
    'Référence 4',
    'Employment by economic activity Agriculture\n(%) 1996-2005',
    'Référence 5',
    'Employment by economic activity Industry\n(%) 1996-2005',
    'Référence 6',
    'Employment by economic activity Services\n(%) 1996-2005',
    'Référence 7',
    'Employment in informal sector as a % of non-agricultural employment Survey year',
    'Référence 8',
    'Employment in informal sector as a % of non-agricultural employment Both sexes\n(%)',
    'Référence 9',
    'Employment in informal sector as a % of non-agricultural employment Female \n(%)',
    'Référence 10',
    'Employment in informal sector as a % of non-agricultural employment Male \n(%)',
    'Référence 11'
]

# %%
# Réinitialiser les colonnes des cadres de données
df.columns = columns
#Supprimer les lignes qui contenaient les informations que nous avons déjà et réinitialiser l'index
df = df.drop(np.arange(3), axis=0).reset_index(drop=True)
df.head()
# Out:
#                  HDI rank                 Country  \
# 0  HIGH HUMAN DEVELOPMENT                     NaN
# 1                      21  Hong Kong, China (SAR)
# 2                      23                  Israel
# 3                      25               Singapore
# 4                      27                Slovenia
#
#   Unemployed people\n(thousands) 1996-2005 Référence 1  \
# 0                                      NaN         NaN
# 1                                      201         NaN
# 2                                      246         NaN
# 3                                      116         NaN
# 4                                       58         NaN
#
#   Unemployment rate Total\n(% of labour force) 1996-2005 Référence 2  \
# 0                                                NaN             NaN
# 1                                                5.6             NaN
# 2                                                9.0             NaN
# ...

# %%
df.tail()
# Out:
#                                               HDI rank       Country  \
# 120                                                176  Burkina Faso
# 121                                              NOTES           NaN
# 122  Data are not strictly comparable across countr...           NaN
# 123  a. Data refer to the ILO definition of unemplo...           NaN
# 124  SOURCES\nColumns 1–3: ILO 2007b. \nColumns 4–7...           NaN
#
#     Unemployed people\n(thousands) 1996-2005 Référence 1  \
# 120                                        7           e
# 121                                      NaN         NaN
# 122                                      NaN         NaN
# 123                                      NaN         NaN
# 124                                      NaN         NaN
#
#     Unemployment rate Total\n(% of labour force) 1996-2005 Référence 2  \
# 120                                                 ..             NaN
# ...

# %%
df.tail(50)
# Out:
#                                               HDI rank  \
# 75                                                 112
# 76                                                 113
# 77                                                 114
# 78                                                 115
# 79                                                 116
# 80                                                 117
# 81                                                 118
# 82                                                 121
# 83                                                 122
# 84                                                 124
# 85                                                 125
# 86                                                 126
# 87                                                 128
# 88                                                 130
# 89                                                 131
# 90                                                 132
# ...

# %%
#Enregistrer les informations autres que les données contenues dans le dataframe

df_notes = df.iloc[121:124,]
df_src = df.iloc[124:125,]

df_notes = df_notes.dropna(how = 'any', axis = 1).reset_index(drop=True)
df_src = df_src.dropna(how = 'any', axis = 1).reset_index(drop=True)

df_notes
df_src
# Out:
#                                             HDI rank
# 0  SOURCES\nColumns 1–3: ILO 2007b. \nColumns 4–7...

# %%
df_notes
# Out:
#                                             HDI rank
# 0                                              NOTES
# 1  Data are not strictly comparable across countr...
# 2  a. Data refer to the ILO definition of unemplo...

# %%
df_src.columns = ["SOURCES"]
df_notes.columns = ["NOTES"]
df_notes = df_notes.drop(np.arange(1), axis= 0).reset_index(drop=True)

# %%
df_src
# Out:
#                                              SOURCES
# 0  SOURCES\nColumns 1–3: ILO 2007b. \nColumns 4–7...

# %%
df_notes
# Out:
#                                                NOTES
# 0  Data are not strictly comparable across countr...
# 1  a. Data refer to the ILO definition of unemplo...

# %%
df = df.drop(np.arange(121,len(df)), axis=0).reset_index(drop=True)

hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]


df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
df.loc[:, "HDI category"] = np.where(df["HDI rank"] < 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] < 70,
                                              "MEDIUM HUMAN DEVELOPMENT",
                                              "HIGH HUMAN DEVELOPMENT"
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)
df
# Out:
#     HDI rank                   Country  \
# 0         21    Hong Kong, China (SAR)
# 1         23                    Israel
# 2         25                 Singapore
# 3         27                  Slovenia
# 4         28                    Cyprus
# ..       ...                       ...
# 113      170                      Chad
# 114      171  Central African Republic
# 115      172                Mozambique
# 116      173                      Mali
# 117      176              Burkina Faso
#
#     Unemployed people\n(thousands) 1996-2005 Référence 1  \
# 0                                        201         NaN
# 1                                        246         NaN
# 2                                        116         NaN
# 3                                         58         NaN
# 4                                         19         NaN
# ..                                       ...         ...
# 113                                       ..         NaN
# ...

# %%
#Enregistrons nos données

with pd.ExcelWriter('HDR 2007-2008 Table 21.xlsx') as writer:
    df.to_excel(writer, sheet_name = 'Table_21', index = False)
    df_notes.to_excel(writer, sheet_name = 'NOTES', index = False)
    df_src.to_excel(writer, sheet_name = 'SOURCES', index = False)
